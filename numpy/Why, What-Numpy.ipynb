# %% [markdown]
# Source - Vizuara
#
# issues in Python
#
# slow : python loops are interpreted, not compiled
# memory inefficient
# No vectorzied operations
# No build matrix operations or broadcasting like array a =a *4

# %% [markdown]
# Numpyt changed everything
# Introduced in early 2000s - based in numeric, Numarray)
# Supports
# >  Multi-dimensional arrays(ndarray)
# >  Vectorized Operations
# > Linear Algebra, Statisitics, Bradcasting
# Foundation for Pandas, scikit-learn, Tensorflow early version

# %% [markdown]
# Did you know?
#
# Most of numpy based C, C++ - partially python
# Numpy revolutionized ML and data science

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Reshaping and aggregaton
